# %% [markdown]
# # In this assignment, you will be analyzing & visualizing several features in the Medical Dataset.
#
# The features to analyze:
# - VitD_levels
# - Doc_visits
# - TotalCharge
#
# For each feature listed:
#
# 1. Plot a histogram with a kde (kernel density estimate)
#     - Add a line for the mean (red)
#     - Add a line for the median (green)
#     - Add a line for for +1 std from the mean (black)
#     - Add a line for the - 1 std from the mean (black)
#     - Highlight the range between +1 and =1 std (yellow)
#
#
# 2. Answer the following questions:
#     - Is it Discrete or Continuous?
#     - Does it have a skew? If so, which direction (+/-)
#     - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# CSV File
filename = 'Data/medical.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# ## VitD_levels
#
# 1. Plot a histogram with a kde (kernel density estimate)
#     - Add a line for the mean (red)
#     - Add a line for the median (green)
#     - Add a line for for +1 std from the mean (black)
#     - Add a line for the - 1 std from the mean (black)
#     - Highlight the range between +1 and =1 std (yellow)

# %%
# Assign Column
col = 'VitD_levels'
# Define Feature
feature = df[col]

# Find mean and median
mean = feature.mean()
median = feature.median()

# Standard Deviation, +/- from mean
std = feature.std()
plus_std = mean + std
minus_std = mean - std

# %%
# Histogram
# Figure
fig,ax = plt.subplots(figsize=(10,6))
# hist plot
sns.histplot(feature , kde = True)
# title
ax.set_title('Vitamin D Levels')
# mean and median with lables for legend
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, color = 'green', label = f'Median = {median:,.2f}')
# standard deviation with lables for legend
ax.axvline(plus_std, color = 'black',label=f'+1 std = {plus_std:,.2f}')
ax.axvline(minus_std, color = 'black', label = f'-1 std = {minus_std:,.2f}')
# highlight for std range
ax.axvspan(plus_std, minus_std, color = 'yellow', zorder = 0)

ax.legend();

# %%
from scipy import stats
# Kurtosis calculation
kurt = stats.kurtosis(feature, fisher = False)

kurt
# Out:
# 3.013147515833447

# %% [markdown]
# 2. Answer the following questions:
#
#     - Is it Discrete or Continuous?
#         - Answer: Continuous, histogram doesn't has spaces.
#     - Does it have a skew? If so, which direction (+/-)
#      - Answer: Positive skew.
#     - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#      - Answer: Normal, Medokurtic. Calculation is ~3

# %% [markdown]
# ## Doc_visits
#
# 1. Plot a histogram with a kde (kernel density estimate)
#     - Add a line for the mean (red)
#     - Add a line for the median (green)
#     - Add a line for for +1 std from the mean (black)
#     - Add a line for the - 1 std from the mean (black)
#     - Highlight the range between +1 and =1 std (yellow)

# %%
# Assign Column
col = 'Doc_visits'
# Define Feature
feature = df[col]

# Find mean and median
mean = feature.mean()
median = feature.median()

# Standard Deviation, +/- from mean
std = feature.std()
plus_std = mean + std
minus_std = mean - std

# %%
# Histogram
# Figure
fig,ax = plt.subplots(figsize=(10,6))
# hist plot
sns.histplot(feature , kde = True)
# title
ax.set_title('Doctor Visits')
# mean and median with lables for legend
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, color = 'green', label = f'Median = {median:,.2f}')
# standard deviation with lables for legend
ax.axvline(plus_std, color = 'black',label=f'+1 std = {plus_std:,.2f}')
ax.axvline(minus_std, color = 'black', label = f'-1 std = {minus_std:,.2f}')
# highlight for std range
ax.axvspan(plus_std, minus_std, color = 'yellow', zorder = 0)

ax.legend();

# %%
# Kurtosis calculation
kurt = stats.kurtosis(feature, fisher = False)

kurt
# Out:
# 2.9919958083381206

# %% [markdown]
# 2. Answer the following questions:
#     - Is it Discrete or Continuous?
#         - Answer: Discrete
#     - Does it have a skew? If so, which direction (+/-)
#         - Answer: No skew, mean and median are nearly the same. Normal.
#     - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#         - Answer: Normal, Medokurtic. Calculation is ~3

# %% [markdown]
# ## TotalCharge
#
# 1. Plot a histogram with a kde (kernel density estimate)
#     - Add a line for the mean (red)
#     - Add a line for the median (green)
#     - Add a line for for +1 std from the mean (black)
#     - Add a line for the - 1 std from the mean (black)
#     - Highlight the range between +1 and =1 std (yellow)

# %%
# Assign Column
col = 'TotalCharge'
# Define Feature
feature = df[col]

# Find mean and median
mean = feature.mean()
median = feature.median()

# Standard Deviation, +/- from mean
std = feature.std()
plus_std = mean + std
minus_std = mean - std

# %%
# Histogram
# Figure
fig,ax = plt.subplots(figsize=(10,6))
# hist plot
sns.histplot(feature , kde = True)
# title
ax.set_title('Total Charge')
# mean and median with lables for legend
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, color = 'green', label = f'Median = {median:,.2f}')
# standard deviation with lables for legend
ax.axvline(plus_std, color = 'black',label=f'+1 std = {plus_std:,.2f}')
ax.axvline(minus_std, color = 'black', label = f'-1 std = {minus_std:,.2f}')
# highlight for std range
ax.axvspan(plus_std, minus_std, color = 'yellow', zorder = 0)

ax.legend();

# %%
# Kurtosis calculation
kurt = stats.kurtosis(feature, fisher = False)

kurt
# Out:
# 3.2650077463439384

# %% [markdown]
# 2. Answer the following questions:
#     - Is it Discrete or Continuous?
#      - Answer: Continus
#     - Does it have a skew? If so, which direction (+/-)
#      - Answer: Positive skew, larger amount to the left of the mean.
#     - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#      - Answer:  Positive, Leptokurtic. Calculation greater than 3.
